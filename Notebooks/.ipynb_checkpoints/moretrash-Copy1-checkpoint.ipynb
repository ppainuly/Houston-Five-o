# %%
#Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import sqlalchemy
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# %%
engine = engine = create_engine('postgresql://live_crimehtx:%7C_IVE_C%7C3IME_hTX001@crimehtxdb.c0fjj9b9p4wl.us-east-1.rds.amazonaws.com/crimehtxdb')
Base = declarative_base(bind=engine)
Session = sessionmaker(bind=engine)
session = Session()

conn = session.bind

# %%
nb = 'LAKE HOUSTON' 
this = "\'"+nb+"\'"

# %%
query = f"Select * from incident_hour_count where snbname = {this}"
df = pd.read_sql_query(query, engine)
df.head()
# Out:
#   hour         offensetype       snbname
# 0   23            Burglary  LAKE HOUSTON
# 1   23  Aggravated Assault  LAKE HOUSTON
# 2   23            Burglary  LAKE HOUSTON
# 3   23            Burglary  LAKE HOUSTON
# 4   23               Theft  LAKE HOUSTON

# %%
attempt = df.groupby(["hour"], as_index=False).count()
attempt
# Out:
#    hour  offensetype  snbname
# 0     0           10       10
# 1     1            1        1
# 2    10            7        7
# 3    11            8        8
# 4    12            9        9
# 5    13            7        7
# 6    14            6        6
# 7    15            7        7
# 8    16            9        9
# 9    17            4        4
# 10   18            6        6
# 11   19            1        1
# 12    2            2        2
# 13   20            7        7
# 14   21            6        6
# 15   22            7        7
# 16   23            7        7
# 17    3            3        3
# 18    5            3        3
# 19    6            7        7
# 20    7            4        4
# 21    8            8        8
# 22    9            5        5

# %%
# use the list to select a subset of the original DataFrame
X = attempt.hour.values.reshape(-1, 1)

y = attempt.snbname.values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (23, 1) (23, 1)

# %%
# X
# y
X = X.astype(int)

# %%
plt.scatter(X, y)

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

### BEGIN SOLUTION

model = LinearRegression()
model

### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Fit the model to the data. 
# Note: This is the training step where you fit the line to the data.
##X is input value, y is predicted value...
### BEGIN SOLUTION

model.fit(X, y)
print(model)
### END SOLUTION
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Print the coefficient and the intercept for the model

### BEGIN SOLUTION
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
### END SOLUTION
# Out:
# Weight coefficients:  [[0.08183267]]
# y-axis intercept:  [4.85832669]

# %%
# predictions

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# look at that prediction error, it's negative????
# Out:
# True output: [10]
# Predicted output: [4.85832669]
# Prediction Error: [-5.14167331]

# %%
predictions
# Out:
# array([[4.85832669],
#        [4.94015936],
#        [5.67665339],
#        [5.75848606],
#        [5.84031873],
#        [5.92215139],
#        [6.00398406],
#        [6.08581673],
#        [6.1676494 ],
#        [6.24948207],
#        [6.33131474],
#        [6.41314741],
#        [5.02199203],
#        [6.49498008],
#        [6.57681275],
#        [6.65864542],
#        [6.74047809],
#        [5.1038247 ],
#        [5.26749004],
#        [5.34932271],
#        [5.43115538],
#        [5.51298805],
#        [5.59482072]])

# %%
# pd.DataFrame({"Predicted": predictions, "Actual": y, "Error": predictions - y})[["Predicted", "Actual", "Error"]]
# ValueError: If using all scalar values, you must pass an index

# %%
# # We can calculate the output response for the minimum and maximum input values. Note: This is useful later when we want to plot the fit line. 
# x_min = X.min()
# x_max = X.max()
# y_min_actual = y.min()
# y_max_actual = y.max()
# # y_max_actual
# # y_min_actual

# %%
# y_min = 40.77 + 2.47652174 * x_min
# y_max = 40.77 + 2.47652174 * x_max
# print(f"Actual Min Value: {y_min_actual}")
# print(f"Calculated Min Value: {y_min}")
# print(f"Actual Max Value: {y_max_actual}")
# print(f"Calculated Max Value: {y_max}")

# %%
#We can also use the predict function to calculate predicted values In 
#same as above, just a diferent method to get it

# y_min_predicted = model.predict([[x_min]])
# y_max_predicted = model.predict([[x_max]])
# print(f"Actual Min Value: {y_min_actual}")
# print(f"Predicted Min Value: {y_min_predicted}")
# print(f"Actual Max Value: {y_max_actual}")
# print(f"Predicted Max Value: {y_max_predicted}")

# %%
# # We can show the model fit by plotting the predicted values against the original data
# plt.scatter(X, y, c='blue')
# plt.plot([x_min, x_max], [y_min_predicted, y_max_predicted], c='red')
# plt.xlabel("Hour")
# plt.ylabel("Count")

# %% [markdown]
# Quantifying the model: is this model working or not, is it better than another model...?

# %%
# from sklearn.metrics import mean_squared_error, r2_score

# # Use our model to predict a value
# predicted = model.predict(X)

# # Score the prediction with mse and r2
# mse = mean_squared_error(y, predicted)
# r2 = r2_score(y, predicted)

# print(f"Mean Squared Error (MSE): {mse}")
# print(f"R-squared (R2): {r2}")


# # A "good" MSE score will be close to zero while a "good" R2 Score will be close to 1.
# # Higher r2 values signify that the model is highly predicative. 
# # An r2 of >.90 means our model roughly accounts for 90% of the 
# # variabiliy of the data.

# %%
#  # Overall Score for the model
# model.score(X, y)
# # Yikes, but look at the plot

# %%
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=42)
# -taking out strafy works w/ and w/o adding a test size


# ValueError: The least populated class in y has only 1 member, which is too few. 
# The minimum number of groups for any class cannot be less than 2.
#    -->I confirm the above explanation. I have encountered this situation when dealing with a class that has a very low count . You can either take a random sample (not stratified) or try different test_size values, to be able to have an adequate size that could hold all your various labels.

# %%
print('Training X Shape:', X_train.shape)
print('Training y Shape:', y_train.shape)
print('Testing X Shape:', X_test.shape)
print('Testing Y Shape:', y_test.shape)
# Out:
# Training X Shape: (17, 1)
# Training y Shape: (17, 1)
# Testing X Shape: (6, 1)
# Testing Y Shape: (6, 1)

# %%
#  Train the model using the training data
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# And score the model using the unseen testing data
model.score(X_test, y_test)
# Out:
# 0.0198922882630701

# %%
s = nb

# %%
# df = pd.DataFrame({'Hour': [X], 'Predictions': [predictions]})
# print(df)

import numpy as np
arr_X = np.array(X)
df = pd.DataFrame(data=arr_X.flatten())
df
# Out:
#      0
# 0    0
# 1    1
# 2   10
# 3   11
# 4   12
# 5   13
# 6   14
# 7   15
# 8   16
# 9   17
# 10  18
# 11  19
# 12   2
# 13  20
# 14  21
# 15  22
# 16  23
# 17   3
# 18   5
# 19   6
# 20   7
# 21   8
# 22   9

# %%
arr_pre = np.array(predictions)
df2 = pd.DataFrame(data=arr_pre.flatten())
df2
# Out:
#            0
# 0   4.858327
# 1   4.940159
# 2   5.676653
# 3   5.758486
# 4   5.840319
# 5   5.922151
# 6   6.003984
# 7   6.085817
# 8   6.167649
# 9   6.249482
# 10  6.331315
# 11  6.413147
# 12  5.021992
# 13  6.494980
# 14  6.576813
# 15  6.658645
# 16  6.740478
# 17  5.103825
# 18  5.267490
# 19  5.349323
# 20  5.431155
# 21  5.512988
# 22  5.594821

# %%
result = pd.concat([df, df2], axis = 1, join_axes=[df.index])
result
# Out:
#      0         0
# 0    0  4.858327
# 1    1  4.940159
# 2   10  5.676653
# 3   11  5.758486
# 4   12  5.840319
# 5   13  5.922151
# 6   14  6.003984
# 7   15  6.085817
# 8   16  6.167649
# 9   17  6.249482
# 10  18  6.331315
# 11  19  6.413147
# 12   2  5.021992
# 13  20  6.494980
# 14  21  6.576813
# 15  22  6.658645
# 16  23  6.740478
# 17   3  5.103825
# 18   5  5.267490
# 19   6  5.349323
# 20   7  5.431155
# 21   8  5.512988
# 22   9  5.594821

# %%
result.columns = ["Hour", "Predictions"]
result
# Out:
#     Hour  Predictions
# 0      0     4.858327
# 1      1     4.940159
# 2     10     5.676653
# 3     11     5.758486
# 4     12     5.840319
# 5     13     5.922151
# 6     14     6.003984
# 7     15     6.085817
# 8     16     6.167649
# 9     17     6.249482
# 10    18     6.331315
# 11    19     6.413147
# 12     2     5.021992
# 13    20     6.494980
# 14    21     6.576813
# 15    22     6.658645
# 16    23     6.740478
# 17     3     5.103825
# 18     5     5.267490
# 19     6     5.349323
# 20     7     5.431155
# 21     8     5.512988
# 22     9     5.594821

# %%
result["snbname"] = s
result
# Out:
#     Hour  Predictions       snbname
# 0      0     4.858327  LAKE HOUSTON
# 1      1     4.940159  LAKE HOUSTON
# 2     10     5.676653  LAKE HOUSTON
# 3     11     5.758486  LAKE HOUSTON
# 4     12     5.840319  LAKE HOUSTON
# 5     13     5.922151  LAKE HOUSTON
# 6     14     6.003984  LAKE HOUSTON
# 7     15     6.085817  LAKE HOUSTON
# 8     16     6.167649  LAKE HOUSTON
# 9     17     6.249482  LAKE HOUSTON
# 10    18     6.331315  LAKE HOUSTON
# 11    19     6.413147  LAKE HOUSTON
# 12     2     5.021992  LAKE HOUSTON
# 13    20     6.494980  LAKE HOUSTON
# 14    21     6.576813  LAKE HOUSTON
# 15    22     6.658645  LAKE HOUSTON
# 16    23     6.740478  LAKE HOUSTON
# 17     3     5.103825  LAKE HOUSTON
# 18     5     5.267490  LAKE HOUSTON
# 19     6     5.349323  LAKE HOUSTON
# 20     7     5.431155  LAKE HOUSTON
# 21     8     5.512988  LAKE HOUSTON
# 22     9     5.594821  LAKE HOUSTON

# %%
result.to_sql('regression_data', con=engine, if_exists='append',method = 'multi',chunksize=1000,index=False)

# %%
test_df = pd.read_sql_query("SELECT * FROM regression_data", engine)
len(test_df)
# Out:
# 2183
